# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("Superstore Sales Dataset.csv")
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
df = df[['Product ID', 'Category', 'Sub-Category', 'Product Name']]

# %%
df.isnull().sum()
# Out:
# Product ID      0
# Category        0
# Sub-Category    0
# Product Name    0
# dtype: int64

# %%
df.dtypes
# Out:
# Product ID      object
# Category        object
# Sub-Category    object
# Product Name    object
# dtype: object

# %%
df[df.duplicated]
# Out:
#            Product ID         Category Sub-Category  \
# 24    FUR-TA-10000577        Furniture       Tables
# 59    TEC-AC-10002167       Technology  Accessories
# 90    TEC-PH-10004093       Technology       Phones
# 120   OFF-BI-10003910  Office Supplies      Binders
# 139   FUR-FU-10001706        Furniture  Furnishings
# ...               ...              ...          ...
# 9795  OFF-BI-10003429  Office Supplies      Binders
# 9796  OFF-AR-10001374  Office Supplies          Art
# 9797  TEC-PH-10004977       Technology       Phones
# 9798  TEC-PH-10000912       Technology       Phones
# 9799  TEC-AC-10000487       Technology  Accessories
#
#                                            Product Name
# 24        Bretford CR4500 Series Slim Rectangular Table
# 59    Imation 8gb Micro Traveldrive Usb 2.0 Flash Drive
# 90                                   Panasonic Kx-TS550
# 120   DXL Angle-View Binders with Locking Rings by S...
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(7907)

# %%
df = df.copy()
df.drop_duplicates(inplace=True)

# %%
df.duplicated(subset=['Product ID','Product Name']).sum()
# Out:
# np.int64(0)

# %%
df.duplicated(subset=['Product ID']).sum()
# Out:
# np.int64(32)

# %%
df.drop_duplicates(subset=['Product ID'],inplace = True)

# %%
df.duplicated(subset=['Product Name']).sum()
# Out:
# np.int64(44)

# %%
df.drop_duplicates(subset=['Product Name'],inplace = True)

# %%
df.to_csv('Products_Data.csv', index=False)

# %%
table = (df.groupby('Sub-Category')['Product ID'].nunique().sort_values(ascending=False).head(10).reset_index())
table
# Out:
#   Sub-Category  Product ID
# 0        Paper         269
# 1      Binders         208
# 2       Phones         184
# 3  Furnishings         180
# 4          Art         156
# 5  Accessories         144
# 6      Storage         129
# 7   Appliances          96
# 8       Chairs          87
# 9       Labels          70

# %%
table = ( df.groupby('Category')['Product Name'].nunique().sort_values(ascending=False).reset_index())
table
# Out:
#           Category  Product Name
# 0  Office Supplies          1042
# 1       Technology           403
# 2        Furniture           372

# %%
product_counts = (df.groupby(['Category', 'Sub-Category'])['Product ID'].count() .reset_index(name='Total Product Count'))
product_counts
# Out:
#            Category Sub-Category  Total Product Count
# 0         Furniture    Bookcases                   49
# 1         Furniture       Chairs                   87
# 2         Furniture  Furnishings                  180
# 3         Furniture       Tables                   56
# 4   Office Supplies   Appliances                   96
# 5   Office Supplies          Art                  156
# 6   Office Supplies      Binders                  208
# 7   Office Supplies    Envelopes                   44
# 8   Office Supplies    Fasteners                   34
# 9   Office Supplies       Labels                   70
# 10  Office Supplies        Paper                  269
# 11  Office Supplies      Storage                  129
# 12  Office Supplies     Supplies                   36
# 13       Technology  Accessories                  144
# 14       Technology      Copiers                   13
# 15       Technology     Machines                   62
# ...
